# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import matplotlib.font_manager
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# from mpl_toolkits.mplot3d import Axes3D
# import itertools as it

import utils.dataset as dataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
col_1 = 35
col_2 = 44

attack_list = pd.read_csv('../../DATA/SWaT/SWaT_Physical/attack_list.csv', error_bad_lines=False, sep='\t')
train_path = "../../DATA/SWaT/SWaT_Physical/SWaT_Dataset_Normal_v0.csv"
test_path = "../../DATA/SWaT/SWaT_Physical/SWaT_Dataset_Attack_v0.csv"

x_train, y_train, x_test, y_test = dataset.base_dataset(train_path, test_path)

x_train, x_test = dataset.pca_return(x_train, x_test)

x_train = pd.DataFrame(data = x_train[:,[col_1, col_2]], columns = [COL_1, COL_2])
x_test = pd.DataFrame(data = x_test[:,[col_1, col_2]], columns = [COL_1, COL_2])

# x_train = x_train + 0.01*np.random.randn(x_train.shape[0],2)
# x_test = x_test + 0.01*np.random.randn(x_test.shape[0],2)

x = np.concatenate((x_train, x_test), axis=0)

y = np.concatenate((y_train, y_test), axis=0).reshape(-1,1)

final = np.concatenate((x, y), axis=1)

fig = plt.figure(figsize = (16,16))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel("PC" + str(col_1), fontsize = 20)
ax.set_ylabel("PC" + str(col_2), fontsize = 20)
# ax.set_title('PCA', fontsize = 20)
targets = ['Normal', 'Attack']
colors = ['g', 'r']
for target, color in zip(targets,colors):
    indicesToKeep = final[:,2] == target
    ax.scatter(final[indicesToKeep,0]
               , final[indicesToKeep,1]
               , c = color
               , s = 0.01
              ,label = labels)

plt.legend(targets, loc='lower right', fontsize=20 , markerscale=100.)    
ax.grid()
plt.show()

# %%
x[0:100]
# Out:
# array([[40.73524959,  7.99746422],
#        [40.73573703,  7.99644087],
#        [40.73627523,  7.99726934],
#        [40.73688281,  7.99801754],
#        [40.73566405,  7.99864463],
#        [40.73344113,  7.99861339],
#        [40.73256417,  8.00046505],
#        [40.73128825,  8.00184698],
#        [40.73054639,  8.00235892],
#        [40.72636229,  8.00334549],
#        [40.72590513,  8.00440037],
#        [40.72429039,  8.00611738],
#        [40.72133355,  8.00646091],
#        [40.72074422,  8.00701947],
#        [40.71795113,  8.00938815],
#        [40.71779017,  8.01037565],
#        [40.71609303,  8.00960823],
#        [40.71392081,  8.00605406],
#        [40.71342679,  8.00431918],
#        [40.71309284,  8.0020555 ],
#        [40.70691381,  7.99931989],
#        [40.70655316,  8.00000842],
#        [40.70557562,  7.99907335],
#        [40.70399103,  7.99729187],
#        [40.7044857 ,  7.98994624],
#        [40.70508052,  7.988493  ],
#        [40.70515086,  7.98332422],
# ...
